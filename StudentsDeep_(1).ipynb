# %% [markdown]
# <a href="https://colab.research.google.com/github/sadot04/Inteligencia_artificial/blob/main/StudentsDeep_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from re import X
# 0 imports
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
#import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

df = pd.read_csv("student_exam_scores.csv")

# %%
df.isnull().sum()
# Out:
# student_id            0
# hours_studied         0
# sleep_hours           0
# attendance_percent    0
# previous_scores       0
# exam_score            0
# dtype: int64

# %%
df
# Out:
#     student_id  hours_studied  sleep_hours  attendance_percent  \
# 0         S001            8.0          8.8                72.1
# 1         S002            1.3          8.6                60.7
# 2         S003            4.0          8.2                73.7
# 3         S004            3.5          4.8                95.1
# 4         S005            9.1          6.4                89.8
# ..         ...            ...          ...                 ...
# 195       S196           10.5          5.4                94.0
# 196       S197            7.1          6.1                85.1
# 197       S198            1.6          6.9                63.8
# 198       S199           12.0          7.3                50.5
# 199       S200           10.2          6.3                97.4
#
#      previous_scores  exam_score
# 0                 45        30.2
# 1                 55        25.0
# 2                 86        35.8
# 3                 66        34.0
# 4                 71        40.3
# ..               ...         ...
# 195               87        42.7
# 196               92        40.4
# 197               76        28.2
# 198               58        42.0
# 199               68        37.8
#
# [200 rows x 6 columns]

# %%
print("Shape brute:", df.shape)
print("Cols:", list(df.columns))
# Out:
# Shape brute: (200, 6)
# Cols: ['student_id', 'hours_studied', 'sleep_hours', 'attendance_percent', 'previous_scores', 'exam_score']

# %%
SEED= 42
os.environ["PYTHONHASHSEED"] = str(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
X = df[[
    "hours_studied", "sleep_hours", "attendance_percent", "previous_scores"
]].copy()

# %%
y = df["exam_score"].astype(float).values

# %%
num_cols= ["hours_studied", "sleep_hours", "attendance_percent", "previous_scores"]

# %% [markdown]
# En X fueron seleccionadas las variables de hours_studied, sleep_hours, attendance_percent y previous score porque consideramos que son importantes y relevantes a la hora de predecir el exam_score que es la variable objetivo en este dataset

# %%
numeric_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler())
])

# %%
from sklearn.pipeline import Pipeline
preprocess = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, num_cols),
    ],
    remainder = "drop"
)

# %%
X_train_df, X_test_df, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=SEED
)
# Ajustar transformadores en train y transformar ambos

X_train = preprocess.fit_transform(X_train_df)
X_test = preprocess.transform(X_test_df)

X_train = X_train.astype(np.float32)
X_test = X_test.astype(np.float32)

print("Input dims:", X_train.shape[1])
# Out:
# Input dims: 4

# %%
def build_model(input_dim: int) -> tf.keras.Model:
    model = models.Sequential([
        layers.Input(shape=(input_dim,)),
        layers.Dense(32, activation="relu"),
        layers.Dropout(0.20),
        layers.Dense(128, activation="relu"),
        layers.Dropout(0.20),
        layers.Dense(164, activation="relu"),
        layers.Dropout(0.20),
        layers.Dense(1)


    ])
    model.compile(
        optimizer="adam",
        loss="mse",
        metrics=["mae", tf.keras.metrics.RootMeanSquaredError(name="rmse")]
    )
    return model

model = build_model(X_train.shape[1])
model.summary()
# Out:
# Model: "sequential_39"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_142 (Dense)               │ (None, 32)             │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_103 (Dropout)           │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_143 (Dense)               │ (None, 128)            │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_104 (Dropout)           │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_144 (Dense)               │ (None, 164)            │        21,156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_105 (Dropout)           │ (None, 164)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_145 (Dense)               │ (None, 1)              │           165 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 25,705 (100.41 KB)
#  Trainable params: 25,705 (100.41 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# En este caso lo hicimos con 4 capas , una capa que tiene 32 neuorunas, la otra que tiene 128 neuronas, otra que tiene 164 neuronas y otra que tiene 1 sola neurona , esta decision fue debido que con estos cambios realizados nos lanzaba un mejor porcentaje en R^2 donde el mayor resultado que obtuvimos fue de 0.79 , ademas le pusimos un dropout para que el modelo no memorice los datos, ademas de que para el test fue implementado 0.2 de los datos y el 0.8 para el entrenamiento

# %%
cbs = [
    callbacks.EarlyStopping(monitor="val_loss", mode="min", patience=12,
                            restore_best_weights=True),
    callbacks.ModelCheckpoint("weather_best.keras", monitor="val_loss", mode="min",
                              save_best_only=True),
    callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=6)
]

# %%
hist = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=200,
    batch_size=32,
    callbacks=cbs,
    verbose=1
)
# Out:
# Epoch 1/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 1176.5034 - mae: 33.7126 - rmse: 34.2978 - val_loss: 1213.9125 - val_mae: 34.1102 - val_rmse: 34.8412 - learning_rate: 0.0010
# Epoch 2/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 1139.0289 - mae: 33.1394 - rmse: 33.7471 - val_loss: 1178.8473 - val_mae: 33.5845 - val_rmse: 34.3343 - learning_rate: 0.0010
# Epoch 3/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1094.5139 - mae: 32.4554 - rmse: 33.0808 - val_loss: 1135.6838 - val_mae: 32.9247 - val_rmse: 33.6999 - learning_rate: 0.0010
# Epoch 4/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1043.8734 - mae: 31.6447 - rmse: 32.3058 - val_loss: 1078.8922 - val_mae: 32.0371 - val_rmse: 32.8465 - learning_rate: 0.0010
# Epoch 5/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 975.7902 - mae: 30.5388 - rmse: 31.2342 - val_loss: 1003.4083 - val_mae: 30.8192 - val_rmse: 31.6766 - learning_rate: 0.0010
# Epoch 6/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 882.5758 - mae: 28.9208 - rmse: 29.7035 - val_loss: 904.8450 - val_mae: 29.1517 - val_rmse: 30.0806 - learning_rate: 0.0010
# Epoch 7/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 775.4336 - mae: 26.9244 - rmse: 27.8391 - val_loss: 780.2469 - val_mae: 26.8949 - val_rmse: 27.9329 - learning_rate: 0.0010
# Epoch 8/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 645.8481 - mae: 24.3647 - rmse: 25.4003 - val_loss: 630.0225 - val_mae: 23.8829 - val_rmse: 25.1002 - learning_rate: 0.0010
# Epoch 9/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 495.2297 - mae: 20.9619 - rmse: 22.2368 - val_loss: 463.0986 - val_mae: 19.9825 - val_rmse: 21.5197 - learning_rate: 0.0010
# Epoch 10/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 347.4845 - mae: 17.0711 - rmse: 18.6189 - val_loss: 299.9994 - val_mae: 15.2096 - val_rmse: 17.3205 - learning_rate: 0.0010
# Epoch 11/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 216.4053 - mae: 13.1010 - rmse: 14.6958 - val_loss: 171.3348 - val_mae: 10.9239 - val_rmse: 13.0895 - learning_rate: 0.0010
# Epoch 12/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 144.7295 - mae: 9.8021 - rmse: 12.0257 - val_loss: 103.6283 - val_mae: 8.2927 - val_rmse: 10.1798 - learning_rate: 0.0010
# Epoch 13/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 126.6855 - mae: 8.5701 - rmse: 11.2168 - val_loss: 82.5533 - val_mae: 7.6036 - val_rmse: 9.0859 - learning_rate: 0.0010
# Epoch 14/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 136.2150 - mae: 9.0967 - rmse: 11.6683 - val_loss: 73.3647 - val_mae: 7.0841 - val_rmse: 8.5653 - learning_rate: 0.0010
# Epoch 15/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 117.9975 - mae: 8.6387 - rmse: 10.8522 - val_loss: 69.2022 - val_mae: 6.6425 - val_rmse: 8.3188 - learning_rate: 0.0010
# Epoch 16/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 93.4635 - mae: 7.7096 - rmse: 9.6638 - val_loss: 73.1051 - val_mae: 6.8592 - val_rmse: 8.5502 - learning_rate: 0.0010
# Epoch 17/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 70.8388 - mae: 6.7782 - rmse: 8.4087 - val_loss: 76.6296 - val_mae: 7.0894 - val_rmse: 8.7538 - learning_rate: 0.0010
# Epoch 18/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 75.2767 - mae: 7.1574 - rmse: 8.6736 - val_loss: 76.3817 - val_mae: 7.0610 - val_rmse: 8.7397 - learning_rate: 0.0010
# Epoch 19/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 66.6916 - mae: 6.9042 - rmse: 8.1541 - val_loss: 71.6841 - val_mae: 6.8097 - val_rmse: 8.4666 - learning_rate: 0.0010
# Epoch 20/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 80.0939 - mae: 7.2826 - rmse: 8.9402 - val_loss: 63.1736 - val_mae: 6.3667 - val_rmse: 7.9482 - learning_rate: 0.0010
# Epoch 21/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 69.5733 - mae: 6.4537 - rmse: 8.3372 - val_loss: 55.2287 - val_mae: 5.9920 - val_rmse: 7.4316 - learning_rate: 0.0010
# Epoch 22/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 67.8931 - mae: 6.4059 - rmse: 8.2394 - val_loss: 51.5839 - val_mae: 5.8282 - val_rmse: 7.1822 - learning_rate: 0.0010
# Epoch 23/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 69.2433 - mae: 6.6415 - rmse: 8.3185 - val_loss: 50.0937 - val_mae: 5.7533 - val_rmse: 7.0777 - learning_rate: 0.0010
# Epoch 24/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 54.2683 - mae: 5.9212 - rmse: 7.3561 - val_loss: 50.3992 - val_mae: 5.7871 - val_rmse: 7.0992 - learning_rate: 0.0010
# Epoch 25/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 74.2845 - mae: 7.0672 - rmse: 8.6172 - val_loss: 52.3726 - val_mae: 5.9331 - val_rmse: 7.2369 - learning_rate: 0.0010
# Epoch 26/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 57.9052 - mae: 6.2318 - rmse: 7.6065 - val_loss: 53.4385 - val_mae: 6.0068 - val_rmse: 7.3102 - learning_rate: 0.0010
# Epoch 27/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 54.1772 - mae: 6.1962 - rmse: 7.3598 - val_loss: 51.9078 - val_mae: 5.9289 - val_rmse: 7.2047 - learning_rate: 0.0010
# Epoch 28/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 65.4493 - mae: 6.2557 - rmse: 8.0812 - val_loss: 51.7999 - val_mae: 5.9320 - val_rmse: 7.1972 - learning_rate: 0.0010
# Epoch 29/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 57.7666 - mae: 6.2285 - rmse: 7.5967 - val_loss: 49.6123 - val_mae: 5.8158 - val_rmse: 7.0436 - learning_rate: 0.0010
# Epoch 30/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 51.5459 - mae: 5.9647 - rmse: 7.1750 - val_loss: 46.0021 - val_mae: 5.5954 - val_rmse: 6.7825 - learning_rate: 0.0010
# Epoch 31/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 57.2550 - mae: 6.0424 - rmse: 7.5656 - val_loss: 43.7645 - val_mae: 5.4742 - val_rmse: 6.6155 - learning_rate: 0.0010
# Epoch 32/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 56.1545 - mae: 6.0436 - rmse: 7.4882 - val_loss: 42.5817 - val_mae: 5.4163 - val_rmse: 6.5255 - learning_rate: 0.0010
# Epoch 33/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 67.5791 - mae: 6.6223 - rmse: 8.2117 - val_loss: 44.1330 - val_mae: 5.4949 - val_rmse: 6.6433 - learning_rate: 0.0010
# Epoch 34/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 54.2028 - mae: 6.1016 - rmse: 7.3577 - val_loss: 47.1655 - val_mae: 5.6848 - val_rmse: 6.8677 - learning_rate: 0.0010
# Epoch 35/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 50.2610 - mae: 5.6874 - rmse: 7.0834 - val_loss: 46.0132 - val_mae: 5.6245 - val_rmse: 6.7833 - learning_rate: 0.0010
# Epoch 36/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 54.0723 - mae: 5.9651 - rmse: 7.3355 - val_loss: 42.7783 - val_mae: 5.4263 - val_rmse: 6.5405 - learning_rate: 0.0010
# Epoch 37/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 59.0436 - mae: 6.3371 - rmse: 7.6734 - val_loss: 39.2431 - val_mae: 5.2323 - val_rmse: 6.2644 - learning_rate: 0.0010
# Epoch 38/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 53.5438 - mae: 5.8755 - rmse: 7.3119 - val_loss: 37.2678 - val_mae: 5.1167 - val_rmse: 6.1047 - learning_rate: 0.0010
# Epoch 39/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 49.7210 - mae: 5.7188 - rmse: 7.0479 - val_loss: 37.6395 - val_mae: 5.1241 - val_rmse: 6.1351 - learning_rate: 0.0010
# Epoch 40/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 55.2806 - mae: 6.0302 - rmse: 7.4314 - val_loss: 39.2723 - val_mae: 5.2507 - val_rmse: 6.2668 - learning_rate: 0.0010
# Epoch 41/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 54.9974 - mae: 6.1580 - rmse: 7.4124 - val_loss: 40.7606 - val_mae: 5.3563 - val_rmse: 6.3844 - learning_rate: 0.0010
# Epoch 42/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 46.5627 - mae: 5.7220 - rmse: 6.8214 - val_loss: 38.5549 - val_mae: 5.2201 - val_rmse: 6.2093 - learning_rate: 0.0010
# Epoch 43/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 50.3369 - mae: 5.7893 - rmse: 7.0921 - val_loss: 36.2067 - val_mae: 5.0620 - val_rmse: 6.0172 - learning_rate: 0.0010
# Epoch 44/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 50.2532 - mae: 5.5172 - rmse: 7.0877 - val_loss: 35.9035 - val_mae: 5.0580 - val_rmse: 5.9920 - learning_rate: 0.0010
# Epoch 45/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 48.8919 - mae: 5.9120 - rmse: 6.9920 - val_loss: 36.1164 - val_mae: 5.0803 - val_rmse: 6.0097 - learning_rate: 0.0010
# Epoch 46/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 49.5493 - mae: 5.6598 - rmse: 7.0378 - val_loss: 34.4447 - val_mae: 4.9848 - val_rmse: 5.8690 - learning_rate: 0.0010
# Epoch 47/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 48.5525 - mae: 5.8026 - rmse: 6.9585 - val_loss: 33.2143 - val_mae: 4.9101 - val_rmse: 5.7632 - learning_rate: 0.0010
# Epoch 48/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 60.4902 - mae: 6.2285 - rmse: 7.7770 - val_loss: 33.0851 - val_mae: 4.9106 - val_rmse: 5.7520 - learning_rate: 0.0010
# Epoch 49/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 38.5922 - mae: 5.1034 - rmse: 6.2107 - val_loss: 33.9201 - val_mae: 4.9700 - val_rmse: 5.8241 - learning_rate: 0.0010
# Epoch 50/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 42.1228 - mae: 5.1010 - rmse: 6.4870 - val_loss: 32.7614 - val_mae: 4.9063 - val_rmse: 5.7238 - learning_rate: 0.0010
# Epoch 51/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 47.9050 - mae: 5.5444 - rmse: 6.9208 - val_loss: 31.3996 - val_mae: 4.8117 - val_rmse: 5.6035 - learning_rate: 0.0010
# Epoch 52/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 42.7154 - mae: 5.1455 - rmse: 6.5140 - val_loss: 29.5732 - val_mae: 4.6837 - val_rmse: 5.4381 - learning_rate: 0.0010
# Epoch 53/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 46.7854 - mae: 5.5176 - rmse: 6.8319 - val_loss: 28.1742 - val_mae: 4.5712 - val_rmse: 5.3079 - learning_rate: 0.0010
# Epoch 54/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 51.1132 - mae: 5.7802 - rmse: 7.1482 - val_loss: 28.5820 - val_mae: 4.6143 - val_rmse: 5.3462 - learning_rate: 0.0010
# Epoch 55/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 44.2733 - mae: 5.5515 - rmse: 6.6494 - val_loss: 29.6585 - val_mae: 4.6859 - val_rmse: 5.4460 - learning_rate: 0.0010
# Epoch 56/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 48.4519 - mae: 5.6771 - rmse: 6.9580 - val_loss: 29.3095 - val_mae: 4.6498 - val_rmse: 5.4138 - learning_rate: 0.0010
# Epoch 57/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 43.3335 - mae: 5.4432 - rmse: 6.5799 - val_loss: 27.5613 - val_mae: 4.5176 - val_rmse: 5.2499 - learning_rate: 0.0010
# Epoch 58/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 35.6123 - mae: 4.9408 - rmse: 5.9653 - val_loss: 26.4617 - val_mae: 4.4225 - val_rmse: 5.1441 - learning_rate: 0.0010
# Epoch 59/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 41.9075 - mae: 5.1490 - rmse: 6.4730 - val_loss: 28.4218 - val_mae: 4.5561 - val_rmse: 5.3312 - learning_rate: 0.0010
# Epoch 60/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 51.2780 - mae: 5.8448 - rmse: 7.1548 - val_loss: 31.0045 - val_mae: 4.7041 - val_rmse: 5.5682 - learning_rate: 0.0010
# Epoch 61/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 38.4080 - mae: 4.9178 - rmse: 6.1964 - val_loss: 29.1754 - val_mae: 4.5840 - val_rmse: 5.4014 - learning_rate: 0.0010
# Epoch 62/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 48.0140 - mae: 5.7486 - rmse: 6.9213 - val_loss: 26.4262 - val_mae: 4.3998 - val_rmse: 5.1406 - learning_rate: 0.0010
# Epoch 63/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 47.0633 - mae: 5.5459 - rmse: 6.8572 - val_loss: 25.6300 - val_mae: 4.3449 - val_rmse: 5.0626 - learning_rate: 0.0010
# Epoch 64/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 40.3851 - mae: 5.1531 - rmse: 6.3536 - val_loss: 26.7193 - val_mae: 4.4277 - val_rmse: 5.1691 - learning_rate: 0.0010
# Epoch 65/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 39.6018 - mae: 5.1064 - rmse: 6.2864 - val_loss: 28.2324 - val_mae: 4.5349 - val_rmse: 5.3134 - learning_rate: 0.0010
# Epoch 66/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 41.1970 - mae: 5.1865 - rmse: 6.4184 - val_loss: 27.1088 - val_mae: 4.4632 - val_rmse: 5.2066 - learning_rate: 0.0010
# Epoch 67/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 37.7629 - mae: 4.8156 - rmse: 6.1441 - val_loss: 26.0879 - val_mae: 4.3996 - val_rmse: 5.1076 - learning_rate: 0.0010
# Epoch 68/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 40.2472 - mae: 5.3829 - rmse: 6.3356 - val_loss: 24.8019 - val_mae: 4.3122 - val_rmse: 4.9801 - learning_rate: 0.0010
# Epoch 69/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 33.5091 - mae: 4.5316 - rmse: 5.7753 - val_loss: 24.4796 - val_mae: 4.2833 - val_rmse: 4.9477 - learning_rate: 0.0010
# Epoch 70/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 37.1819 - mae: 4.9196 - rmse: 6.0968 - val_loss: 23.1720 - val_mae: 4.1861 - val_rmse: 4.8137 - learning_rate: 0.0010
# Epoch 71/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 35.1845 - mae: 4.8880 - rmse: 5.9305 - val_loss: 21.8258 - val_mae: 4.0586 - val_rmse: 4.6718 - learning_rate: 0.0010
# Epoch 72/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 30.8573 - mae: 4.4202 - rmse: 5.5543 - val_loss: 22.1569 - val_mae: 4.0666 - val_rmse: 4.7071 - learning_rate: 0.0010
# Epoch 73/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 34.8156 - mae: 4.9200 - rmse: 5.8925 - val_loss: 23.5967 - val_mae: 4.1710 - val_rmse: 4.8576 - learning_rate: 0.0010
# Epoch 74/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 34.4574 - mae: 4.9086 - rmse: 5.8690 - val_loss: 22.4048 - val_mae: 4.0811 - val_rmse: 4.7334 - learning_rate: 0.0010
# Epoch 75/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 35.3243 - mae: 4.8232 - rmse: 5.9416 - val_loss: 19.9744 - val_mae: 3.8952 - val_rmse: 4.4693 - learning_rate: 0.0010
# Epoch 76/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 34.3075 - mae: 4.7472 - rmse: 5.8560 - val_loss: 20.1286 - val_mae: 3.9155 - val_rmse: 4.4865 - learning_rate: 0.0010
# Epoch 77/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 32.6882 - mae: 4.7465 - rmse: 5.7141 - val_loss: 20.4049 - val_mae: 3.9384 - val_rmse: 4.5172 - learning_rate: 0.0010
# Epoch 78/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 34.4415 - mae: 4.7365 - rmse: 5.8672 - val_loss: 19.4002 - val_mae: 3.8516 - val_rmse: 4.4046 - learning_rate: 0.0010
# Epoch 79/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 30.1273 - mae: 4.4801 - rmse: 5.4835 - val_loss: 18.0411 - val_mae: 3.7203 - val_rmse: 4.2475 - learning_rate: 0.0010
# Epoch 80/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 26.5054 - mae: 4.0934 - rmse: 5.1369 - val_loss: 16.9476 - val_mae: 3.5979 - val_rmse: 4.1167 - learning_rate: 0.0010
# Epoch 81/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 37.2685 - mae: 4.8796 - rmse: 6.1024 - val_loss: 16.8361 - val_mae: 3.5822 - val_rmse: 4.1032 - learning_rate: 0.0010
# Epoch 82/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 37.2522 - mae: 4.9248 - rmse: 6.0942 - val_loss: 19.3969 - val_mae: 3.7894 - val_rmse: 4.4042 - learning_rate: 0.0010
# Epoch 83/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 30.6127 - mae: 4.3743 - rmse: 5.5270 - val_loss: 21.5187 - val_mae: 3.9352 - val_rmse: 4.6388 - learning_rate: 0.0010
# Epoch 84/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 29.2318 - mae: 4.4254 - rmse: 5.4041 - val_loss: 21.0643 - val_mae: 3.8942 - val_rmse: 4.5896 - learning_rate: 0.0010
# Epoch 85/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 28.5764 - mae: 4.4191 - rmse: 5.3452 - val_loss: 17.0681 - val_mae: 3.5661 - val_rmse: 4.1314 - learning_rate: 0.0010
# Epoch 86/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 27.4793 - mae: 4.4023 - rmse: 5.2414 - val_loss: 16.1125 - val_mae: 3.4897 - val_rmse: 4.0140 - learning_rate: 0.0010
# Epoch 87/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 26.1989 - mae: 4.2324 - rmse: 5.1181 - val_loss: 16.7892 - val_mae: 3.5706 - val_rmse: 4.0975 - learning_rate: 0.0010
# Epoch 88/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 29.4347 - mae: 4.4625 - rmse: 5.4236 - val_loss: 16.6570 - val_mae: 3.5498 - val_rmse: 4.0813 - learning_rate: 0.0010
# Epoch 89/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 35.2627 - mae: 4.6284 - rmse: 5.9340 - val_loss: 15.6067 - val_mae: 3.4413 - val_rmse: 3.9505 - learning_rate: 0.0010
# Epoch 90/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 24.9240 - mae: 4.0226 - rmse: 4.9851 - val_loss: 15.4733 - val_mae: 3.4198 - val_rmse: 3.9336 - learning_rate: 0.0010
# Epoch 91/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 26.8142 - mae: 4.0885 - rmse: 5.1704 - val_loss: 16.1454 - val_mae: 3.4517 - val_rmse: 4.0181 - learning_rate: 0.0010
# Epoch 92/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 28.5181 - mae: 4.3898 - rmse: 5.3400 - val_loss: 15.2013 - val_mae: 3.3529 - val_rmse: 3.8989 - learning_rate: 0.0010
# Epoch 93/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 24.6266 - mae: 3.8963 - rmse: 4.9612 - val_loss: 13.3872 - val_mae: 3.1610 - val_rmse: 3.6589 - learning_rate: 0.0010
# Epoch 94/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 29.4389 - mae: 4.4734 - rmse: 5.4178 - val_loss: 13.3859 - val_mae: 3.1624 - val_rmse: 3.6587 - learning_rate: 0.0010
# Epoch 95/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 27.1742 - mae: 4.3025 - rmse: 5.2113 - val_loss: 13.6456 - val_mae: 3.1871 - val_rmse: 3.6940 - learning_rate: 0.0010
# Epoch 96/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 26.2531 - mae: 4.1074 - rmse: 5.1177 - val_loss: 16.5723 - val_mae: 3.4118 - val_rmse: 4.0709 - learning_rate: 0.0010
# Epoch 97/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 25.8422 - mae: 4.1369 - rmse: 5.0822 - val_loss: 15.7924 - val_mae: 3.3458 - val_rmse: 3.9740 - learning_rate: 0.0010
# Epoch 98/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 21.2073 - mae: 3.7140 - rmse: 4.6042 - val_loss: 13.4180 - val_mae: 3.1149 - val_rmse: 3.6631 - learning_rate: 0.0010
# Epoch 99/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 21.8516 - mae: 3.7745 - rmse: 4.6728 - val_loss: 12.4684 - val_mae: 2.9465 - val_rmse: 3.5311 - learning_rate: 0.0010
# Epoch 100/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 23.8943 - mae: 4.0843 - rmse: 4.8880 - val_loss: 12.4868 - val_mae: 2.9583 - val_rmse: 3.5337 - learning_rate: 0.0010
# Epoch 101/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 21.6697 - mae: 3.7439 - rmse: 4.6521 - val_loss: 12.9049 - val_mae: 3.0358 - val_rmse: 3.5923 - learning_rate: 0.0010
# Epoch 102/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 25.8659 - mae: 3.9787 - rmse: 5.0831 - val_loss: 12.8838 - val_mae: 3.0271 - val_rmse: 3.5894 - learning_rate: 0.0010
# Epoch 103/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 25.2291 - mae: 3.9163 - rmse: 5.0154 - val_loss: 16.5329 - val_mae: 3.4289 - val_rmse: 4.0661 - learning_rate: 0.0010
# Epoch 104/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 29.7842 - mae: 4.4754 - rmse: 5.4544 - val_loss: 17.8562 - val_mae: 3.5564 - val_rmse: 4.2257 - learning_rate: 0.0010
# Epoch 105/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 24.4170 - mae: 4.0408 - rmse: 4.9404 - val_loss: 13.1038 - val_mae: 3.0519 - val_rmse: 3.6199 - learning_rate: 0.0010
# Epoch 106/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 25.3613 - mae: 4.1605 - rmse: 5.0357 - val_loss: 11.8783 - val_mae: 2.8527 - val_rmse: 3.4465 - learning_rate: 5.0000e-04
# Epoch 107/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 16.8620 - mae: 3.2682 - rmse: 4.0879 - val_loss: 11.5682 - val_mae: 2.8036 - val_rmse: 3.4012 - learning_rate: 5.0000e-04
# Epoch 108/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 23.9103 - mae: 3.9227 - rmse: 4.8848 - val_loss: 12.4103 - val_mae: 2.9504 - val_rmse: 3.5228 - learning_rate: 5.0000e-04
# Epoch 109/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 22.7648 - mae: 3.8955 - rmse: 4.7634 - val_loss: 12.8859 - val_mae: 3.0197 - val_rmse: 3.5897 - learning_rate: 5.0000e-04
# Epoch 110/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 25.3269 - mae: 4.0902 - rmse: 5.0250 - val_loss: 13.8886 - val_mae: 3.1259 - val_rmse: 3.7267 - learning_rate: 5.0000e-04
# Epoch 111/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 20.6318 - mae: 3.8335 - rmse: 4.5363 - val_loss: 14.4507 - val_mae: 3.1632 - val_rmse: 3.8014 - learning_rate: 5.0000e-04
# Epoch 112/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 28.0793 - mae: 4.0478 - rmse: 5.2979 - val_loss: 13.1269 - val_mae: 3.0084 - val_rmse: 3.6231 - learning_rate: 5.0000e-04
# Epoch 113/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 24.7115 - mae: 3.9744 - rmse: 4.9691 - val_loss: 12.4311 - val_mae: 2.9312 - val_rmse: 3.5258 - learning_rate: 5.0000e-04
# Epoch 114/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 24.1462 - mae: 3.9872 - rmse: 4.9124 - val_loss: 12.5999 - val_mae: 2.9472 - val_rmse: 3.5496 - learning_rate: 2.5000e-04
# Epoch 115/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 25.5693 - mae: 3.9290 - rmse: 5.0565 - val_loss: 12.5133 - val_mae: 2.9357 - val_rmse: 3.5374 - learning_rate: 2.5000e-04
# Epoch 116/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 22.6723 - mae: 3.8685 - rmse: 4.7598 - val_loss: 11.9628 - val_mae: 2.8718 - val_rmse: 3.4587 - learning_rate: 2.5000e-04
# Epoch 117/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 17.3310 - mae: 3.5217 - rmse: 4.1623 - val_loss: 11.4396 - val_mae: 2.8069 - val_rmse: 3.3822 - learning_rate: 2.5000e-04
# Epoch 118/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 20.0796 - mae: 3.6064 - rmse: 4.4713 - val_loss: 11.5371 - val_mae: 2.8165 - val_rmse: 3.3966 - learning_rate: 2.5000e-04
# Epoch 119/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 20.5366 - mae: 3.6742 - rmse: 4.5289 - val_loss: 11.7106 - val_mae: 2.8362 - val_rmse: 3.4221 - learning_rate: 2.5000e-04
# Epoch 120/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 19.5033 - mae: 3.4323 - rmse: 4.4144 - val_loss: 11.7334 - val_mae: 2.8371 - val_rmse: 3.4254 - learning_rate: 2.5000e-04
# Epoch 121/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 19.6569 - mae: 3.5197 - rmse: 4.4217 - val_loss: 12.0634 - val_mae: 2.8716 - val_rmse: 3.4732 - learning_rate: 2.5000e-04
# Epoch 122/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 20.6968 - mae: 3.6183 - rmse: 4.5458 - val_loss: 12.1354 - val_mae: 2.8767 - val_rmse: 3.4836 - learning_rate: 2.5000e-04
# Epoch 123/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 23.1231 - mae: 3.7060 - rmse: 4.8082 - val_loss: 11.9213 - val_mae: 2.8496 - val_rmse: 3.4527 - learning_rate: 2.5000e-04
# Epoch 124/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 21.0684 - mae: 3.7415 - rmse: 4.5773 - val_loss: 11.9035 - val_mae: 2.8473 - val_rmse: 3.4501 - learning_rate: 1.2500e-04
# Epoch 125/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 19.8810 - mae: 3.5909 - rmse: 4.4357 - val_loss: 11.8425 - val_mae: 2.8396 - val_rmse: 3.4413 - learning_rate: 1.2500e-04
# Epoch 126/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 23.4090 - mae: 3.8693 - rmse: 4.8378 - val_loss: 11.6828 - val_mae: 2.8180 - val_rmse: 3.4180 - learning_rate: 1.2500e-04
# Epoch 127/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 23.3750 - mae: 3.7524 - rmse: 4.8343 - val_loss: 11.6602 - val_mae: 2.8134 - val_rmse: 3.4147 - learning_rate: 1.2500e-04
# Epoch 128/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 20.0803 - mae: 3.7279 - rmse: 4.4805 - val_loss: 11.6517 - val_mae: 2.8113 - val_rmse: 3.4135 - learning_rate: 1.2500e-04
# Epoch 129/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 20.3282 - mae: 3.5837 - rmse: 4.5052 - val_loss: 11.6556 - val_mae: 2.8110 - val_rmse: 3.4140 - learning_rate: 1.2500e-04

# %%
y_pred = model.predict(X_test).ravel()

print("\nError Cuadrático Medio (MSE):", mean_squared_error(y_test, y_pred))
print("Error Absoluto Medio (MAE):", mean_absolute_error(y_test, y_pred))
print("Coeficiente de Determinación (R²):", r2_score(y_test, y_pred))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#
# Error Cuadrático Medio (MSE): 11.732715011369777
# Error Absoluto Medio (MAE): 2.8769694232940677
# Coeficiente de Determinación (R²): 0.7789204276726485

# %%
def predict_one(sample: dict) -> float:

    # Convertir a DataFrame con columnas en orden esperado
    s = pd.DataFrame([sample])


    # Aplicar exactamente el mismo procesamiento
    s_proc = preprocess.transform(s[X.columns])
    s_proc = s_proc.astype(np.float32)

    # Predecir
    pred = model.predict(s_proc).item()
    return pred

# %%
sample = {
    "hours_studied":7.0,
    "sleep_hours":8.0,
    "attendance_percent":75.5,
    "previous_scores":80.20,
}
pred = predict_one(sample)
print(f"Predecido {pred:.2f} ")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predecido 35.18
