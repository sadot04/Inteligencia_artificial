# %% [markdown]
# <a href="https://colab.research.google.com/github/sadot04/Inteligencia_artificial/blob/main/Ejercicios_deep_learning_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Ejercicio 2: MLP para resolver el XOR
import numpy as np
from sklearn.neural_network import MLPClassifier

#Datos XOR
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([0, 1, 1, 0]) #Salida XOR

#Red neuronal con 2 capas ocultas de 4 neuronas cada una
mlp = MLPClassifier(hidden_layer_sizes=(4, 4), activation="relu", max_iter=2000)

#Entrenar la red neuronal
mlp.fit(X, y)

#Realizar predicciones
print("Predicciones XOR:", mlp.predict(X))
print("Probabilidades:", mlp.predict_proba(X))
# Out:
# Predicciones XOR: [0 0 1 1]
# Probabilidades: [[0.60027242 0.39972758]
#  [0.54135444 0.45864556]
#  [0.4865032  0.5134968 ]
#  [0.42682816 0.57317184]]
